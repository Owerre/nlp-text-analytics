# %% [markdown]
# # Data Acquisition

# %%
# %matplotlib inline

# filter warnings
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import time
from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams.update({'font.size': 15})

# %%
# Import custom class
# %run -i '../src/helper/scraper.py'

# %%
# Instantiate the class
scraper = Scraper()

# %% [markdown]
#  ## Scraping from the arXiv

# %%
df = scraper.get_data()
# Out:
# 55124|63001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|64001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|65001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|66001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|67001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|68001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|69001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|70001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|71001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|72001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|73001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|74001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|75001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|76001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|77001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|78001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|79001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|80001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|81001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|82001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|83001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|84001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|85001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|86001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|87001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|88001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|89001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|90001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|91001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|92001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|93001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|94001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|95001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|96001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|97001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|98001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|99001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|100001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|101001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|102001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|103001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|104001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|105001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|106001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|107001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|108001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|109001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|110001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|111001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|112001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|113001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|114001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|115001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|116001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|117001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|118001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|119001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|120001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|121001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|122001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|123001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|124001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|125001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|126001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|127001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|128001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|129001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|130001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|131001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|132001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|133001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|134001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|135001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|136001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|137001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|138001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|139001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|140001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|141001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|142001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|143001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|144001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|145001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|146001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|147001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|148001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|149001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|150001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|151001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|152001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|153001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|154001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|155001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|156001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|157001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|158001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|159001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|160001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|161001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|162001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|163001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|164001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|165001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|166001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|167001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|168001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|169001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|170001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|171001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|172001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|173001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|174001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|175001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|176001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|177001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|178001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|179001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|180001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|181001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|182001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|183001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|184001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|185001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|186001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|187001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|188001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|189001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|190001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|191001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|192001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|193001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|194001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|195001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|196001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|197001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|198001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|199001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|200001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|201001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|202001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|203001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|204001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|205001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|206001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|207001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|208001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|209001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|210001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|211001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|212001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|213001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|214001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|215001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|216001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|217001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|218001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|219001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|220001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|221001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|222001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|223001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|224001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|225001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|226001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|227001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|228001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|229001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|230001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|231001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|232001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|233001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|234001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|235001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|236001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|237001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|238001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|239001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|240001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|241001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|242001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|243001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|244001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|245001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|246001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|247001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|248001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|249001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|250001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|251001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|252001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|253001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|254001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|255001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|256001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|257001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|258001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|259001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|260001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|261001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|262001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|263001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|264001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|265001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|266001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|267001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|268001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|269001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|270001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|271001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|272001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|273001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|274001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|275001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|276001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|277001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|278001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|279001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|280001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|281001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|282001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|283001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|284001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|285001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|286001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|287001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|288001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|289001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|290001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|291001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|292001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|293001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|294001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=5355124|295001
# fetching http://export.arxiv.org/oai2?verb=ListRecords&resumptionToken=

# %%
print('Data size:', df.shape)
df.head()
# Out:
# Data size: (295174, 8)
#                                             abstract   arXiv_id  \
# 0    We study the two-particle wave function of p...  0704.0006
# 1    A general formulation was developed to repre...  0704.0008
# 2    We present recent advances in understanding ...  0704.0025
# 3    We describe a peculiar fine structure acquir...  0704.0027
# 4    We investigate the effect of tuning the phon...  0704.0030
#
#                                              authors  \
# 0                              [PongY. H., LawC. K.]
# 1                                   [SwiftDamian C.]
# 2  [MishchenkoA. S.CREST, Japan Science and Techn...
# 3  [GoerbigM. O., FuchsJ. -N., KechedzhiK., Fal'k...
# 4                       [HagueJ. P., d'AmbrumenilN.]
#
#                               categories  \
# 0                    [cond-mat.mes-hall]
# 1                    [cond-mat.mtrl-sci]
# 2  [cond-mat.str-el, cond-mat.stat-mech]
# 3                    [cond-mat.mes-hall]
# 4                      [cond-mat.str-el]
#
#                                             comments date_created  \
# 0                6 pages, 4 figures, accepted by PRA   2007-03-31
# 1                                  Minor corrections   2007-03-31
# 2  41 pages, 13 figures, in "Polarons in Advanced...   2007-04-02
# 3  4 pages, 2 figures; mistakes due to an erroneo...   2007-04-02
# 4    Reprint to improve access. 13 pages, 6 figures.   2007-03-31
#
#                              doi  \
# 0     10.1103/PhysRevA.75.043613
# 1              10.1063/1.2975338
# 2   10.1007/978-1-4020-6348-0_12
# 3  10.1103/PhysRevLett.99.087402
# 4      10.1007/s10909-005-6013-6
#
#                                                title
# 0  Bosonic characters of atomic Cooper pairs acro...
# 1  Numerical solution of shock and ramp compressi...
# 2  Spectroscopic Properties of Polarons in Strong...
# 3  Filling-Factor-Dependent Magnetophonon Resonan...
# 4  Tuning correlation effects with electron-phono...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295174 entries, 0 to 295173
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   abstract      295174 non-null  object
#  1   arXiv_id      295174 non-null  object
#  2   authors       295174 non-null  object
#  3   categories    295174 non-null  object
#  4   comments      240949 non-null  object
#  5   date_created  295174 non-null  object
#  6   doi           234381 non-null  object
#  7   title         295174 non-null  object
# dtypes: object(8)
# memory usage: 18.0+ MB

# %%
# save as csv
df.to_csv('../data/raw_data.csv', sep = '\t', index=False)
